# %%
from dask.distributed import Client

client = Client("tcp://127.0.0.1:37223")
client
# Out:
# <Client: 'tcp://127.0.0.1:37223' processes=8 threads=64, memory=64.00 GiB>

# %%
import numpy as np
import xarray as xr

import gsw

import os.path as op

from matplotlib import ticker
import matplotlib.colors as clr
import matplotlib.pyplot as plt
plt.rcParams['pcolor.shading'] = 'auto'
# %matplotlib inline

# %%
ddir = "/app/SWOT/"

# %%
dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_001_v2.0.1.nc"))
dsH = xr.open_dataset(op.join(ddir,"HYCOM-tidal-correction/hycom_ssh_pass01_swot1day_v2.0.1.nc"))
dsS, dsH
# Out:
# (<xarray.Dataset> Size: 2GB
#  Dimensions:       (cycle_num: 105, num_lines: 9860, num_pixels: 69, pass_num: 1)
#  Coordinates:
#    * cycle_num     (cycle_num) int64 840B 474 475 476 477 478 ... 575 576 577 578
#    * pass_num      (pass_num) int64 8B 1
#      latitude      (num_lines, num_pixels) float64 5MB ...
#      longitude     (num_lines, num_pixels) float64 5MB ...
#  Dimensions without coordinates: num_lines, num_pixels
#  Data variables:
#      time          (cycle_num, num_lines) datetime64[ns] 8MB ...
#      hret          (cycle_num, num_lines, num_pixels) float64 571MB ...
#      duacs_oi      (cycle_num, pass_num, num_lines, num_pixels) float64 571MB ...
#      ssha_filt     (cycle_num, num_lines, num_pixels) float64 571MB ...
#      ssha_filt_ms  (cycle_num, pass_num, num_lines, num_pixels) float64 571MB ...
#  Attributes: (12/49)
#      Conventions:                     CF-1.7
#      Metadata_Conventions:            Unidata Dataset Discovery v1.0
#      cdm_data_type:                   Swath
#      comment:                         Sea Surface Height measured by Altimetry
#      data_used:                       SWOT KaRIn L2_LR_SSH PGC0/PIC0/PIC2 (NAS...
#      doi:                             https://doi.org/10.24400/527896/A01-2023...
#      ...                              ...
#      concated_on:                     Jul 30, 2025  11:08
#      info:                            /home/yadidya/swot_paper/greatlakes/anal...
#      cycles_in_file:                  [475, 476, 478, 479, 480, 481, 482, 483,...
#      description:                     Internal tide correction is added back t...
#      created_by:                      B. Yadidya
#      created_on:                      Jul 30, 2025 15:36,
#  <xarray.Dataset> Size: 2GB
#  Dimensions:      (num_cycle: 105, num_pass: 1, num_lines: 9860, num_pixels: 69)
#  Coordinates:
#    * num_cycle    (num_cycle) int64 840B 474 475 476 477 478 ... 575 576 577 578
#    * num_pass     (num_pass) int64 8B 1
#    * num_lines    (num_lines) int64 79kB 0 1 2 3 4 5 ... 9855 9856 9857 9858 9859
#    * num_pixels   (num_pixels) int64 552B 0 1 2 3 4 5 6 ... 62 63 64 65 66 67 68
#      latitude     (num_lines, num_pixels) float64 5MB ...
#      longitude    (num_lines, num_pixels) float64 5MB ...
#  Data variables:
#      hycom_coh    (num_cycle, num_pass, num_lines, num_pixels) float64 571MB ...
#      hycom_incoh  (num_cycle, num_pass, num_lines, num_pixels) float64 571MB ...
#      hycom_total  (num_cycle, num_pass, num_lines, num_pixels) float64 571MB ...
#  Attributes:
#      description:  Phase-locked and Non-phase-locked internal tides from HYCOM...
#      created_by:   B. Yadidya
#      created_on:   Oct 28, 2025 12:41)

# %%
dsS.ssha_filt.isel(cycle_num=1).plot(rasterized=True)
plt.show()
dsH.hycom_total.isel(num_cycle=1).plot(rasterized=True)
plt.show()

# %%
for i in range(1,29):
    dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_%03d_v2.0.1.nc"
                                  % i),
                          chunks={"cycle_num":1}
                         )
    dsH = xr.open_dataset(op.join(ddir,"HYCOM-tidal-correction/hycom_ssh_pass%02d_swot1day_v2.0.1.nc"
                                  % i),
                          chunks={"num_cycle":1}
                         )

    print(dsS.pass_num.values, dsH.num_pass.values)
    ssh_detided = dsS.ssha_filt - dsH.hycom_total.isel(num_pass=0).data

    ssh_detided.isel(cycle_num=i).plot(rasterized=True)
    plt.show()

    dsave = ssh_detided.to_dataset(name="ssha_detided")
    dsave.to_zarr(op.join(ddir,"SWOT_no_IT/CalVal_pass%03d_v2.0.1.zarr"
                          % i), mode="w"
                 )
    dsave.close()
    dsS.close(), dsH.close()
# Out:
# /tmp/ipykernel_19047/3579314230.py:2: UserWarning: The specified chunks separate the stored chunks along dimension "cycle_num" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_%03d_v2.0.1.nc"
# [1] [1]
# /app/nepcon/miniconda3/envs/dmd/lib/python3.12/site-packages/zarr/api/asynchronous.py:244: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(
# /tmp/ipykernel_19047/3579314230.py:2: UserWarning: The specified chunks separate the stored chunks along dimension "cycle_num" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_%03d_v2.0.1.nc"
# [2] [2]
# /app/nepcon/miniconda3/envs/dmd/lib/python3.12/site-packages/zarr/api/asynchronous.py:244: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(
# /tmp/ipykernel_19047/3579314230.py:2: UserWarning: The specified chunks separate the stored chunks along dimension "cycle_num" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_%03d_v2.0.1.nc"
# [3] [3]
# /app/nepcon/miniconda3/envs/dmd/lib/python3.12/site-packages/zarr/api/asynchronous.py:244: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(
# /tmp/ipykernel_19047/3579314230.py:2: UserWarning: The specified chunks separate the stored chunks along dimension "cycle_num" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_%03d_v2.0.1.nc"
# [4] [4]
# /app/nepcon/miniconda3/envs/dmd/lib/python3.12/site-packages/zarr/api/asynchronous.py:244: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(
# /tmp/ipykernel_19047/3579314230.py:2: UserWarning: The specified chunks separate the stored chunks along dimension "cycle_num" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_%03d_v2.0.1.nc"
# [5] [5]
# /app/nepcon/miniconda3/envs/dmd/lib/python3.12/site-packages/zarr/api/asynchronous.py:244: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(
# /tmp/ipykernel_19047/3579314230.py:2: UserWarning: The specified chunks separate the stored chunks along dimension "cycle_num" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_%03d_v2.0.1.nc"
# [6] [6]
# /app/nepcon/miniconda3/envs/dmd/lib/python3.12/site-packages/zarr/api/asynchronous.py:244: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(
# /tmp/ipykernel_19047/3579314230.py:2: UserWarning: The specified chunks separate the stored chunks along dimension "cycle_num" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_%03d_v2.0.1.nc"
# [7] [7]
# /app/nepcon/miniconda3/envs/dmd/lib/python3.12/site-packages/zarr/api/asynchronous.py:244: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(
# /tmp/ipykernel_19047/3579314230.py:2: UserWarning: The specified chunks separate the stored chunks along dimension "cycle_num" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_%03d_v2.0.1.nc"
# [8] [8]
# /app/nepcon/miniconda3/envs/dmd/lib/python3.12/site-packages/zarr/api/asynchronous.py:244: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(
# /tmp/ipykernel_19047/3579314230.py:2: UserWarning: The specified chunks separate the stored chunks along dimension "cycle_num" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_%03d_v2.0.1.nc"
# [9] [9]
# /app/nepcon/miniconda3/envs/dmd/lib/python3.12/site-packages/zarr/api/asynchronous.py:244: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(
# /tmp/ipykernel_19047/3579314230.py:2: UserWarning: The specified chunks separate the stored chunks along dimension "cycle_num" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_%03d_v2.0.1.nc"
# [10] [10]
# /app/nepcon/miniconda3/envs/dmd/lib/python3.12/site-packages/zarr/api/asynchronous.py:244: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(
# /tmp/ipykernel_19047/3579314230.py:2: UserWarning: The specified chunks separate the stored chunks along dimension "cycle_num" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_%03d_v2.0.1.nc"
# [11] [11]
# /app/nepcon/miniconda3/envs/dmd/lib/python3.12/site-packages/zarr/api/asynchronous.py:244: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(
# /tmp/ipykernel_19047/3579314230.py:2: UserWarning: The specified chunks separate the stored chunks along dimension "cycle_num" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_%03d_v2.0.1.nc"
# [12] [12]
# /app/nepcon/miniconda3/envs/dmd/lib/python3.12/site-packages/zarr/api/asynchronous.py:244: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(
# /tmp/ipykernel_19047/3579314230.py:2: UserWarning: The specified chunks separate the stored chunks along dimension "cycle_num" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_%03d_v2.0.1.nc"
# [13] [13]
# /app/nepcon/miniconda3/envs/dmd/lib/python3.12/site-packages/zarr/api/asynchronous.py:244: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(
# /tmp/ipykernel_19047/3579314230.py:2: UserWarning: The specified chunks separate the stored chunks along dimension "cycle_num" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_%03d_v2.0.1.nc"
# [14] [14]
# /app/nepcon/miniconda3/envs/dmd/lib/python3.12/site-packages/zarr/api/asynchronous.py:244: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(
# /tmp/ipykernel_19047/3579314230.py:2: UserWarning: The specified chunks separate the stored chunks along dimension "cycle_num" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_%03d_v2.0.1.nc"
# [15] [15]
# /app/nepcon/miniconda3/envs/dmd/lib/python3.12/site-packages/zarr/api/asynchronous.py:244: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(
# /tmp/ipykernel_19047/3579314230.py:2: UserWarning: The specified chunks separate the stored chunks along dimension "cycle_num" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_%03d_v2.0.1.nc"
# [16] [16]
# /app/nepcon/miniconda3/envs/dmd/lib/python3.12/site-packages/zarr/api/asynchronous.py:244: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(
# /tmp/ipykernel_19047/3579314230.py:2: UserWarning: The specified chunks separate the stored chunks along dimension "cycle_num" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_%03d_v2.0.1.nc"
# [17] [17]
# /app/nepcon/miniconda3/envs/dmd/lib/python3.12/site-packages/zarr/api/asynchronous.py:244: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(
# /tmp/ipykernel_19047/3579314230.py:2: UserWarning: The specified chunks separate the stored chunks along dimension "cycle_num" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_%03d_v2.0.1.nc"
# [18] [18]
# /app/nepcon/miniconda3/envs/dmd/lib/python3.12/site-packages/zarr/api/asynchronous.py:244: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(
# /tmp/ipykernel_19047/3579314230.py:2: UserWarning: The specified chunks separate the stored chunks along dimension "cycle_num" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_%03d_v2.0.1.nc"
# [19] [19]
# /app/nepcon/miniconda3/envs/dmd/lib/python3.12/site-packages/zarr/api/asynchronous.py:244: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(
# /tmp/ipykernel_19047/3579314230.py:2: UserWarning: The specified chunks separate the stored chunks along dimension "cycle_num" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_%03d_v2.0.1.nc"
# [20] [20]
# /app/nepcon/miniconda3/envs/dmd/lib/python3.12/site-packages/zarr/api/asynchronous.py:244: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(
# /tmp/ipykernel_19047/3579314230.py:2: UserWarning: The specified chunks separate the stored chunks along dimension "cycle_num" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_%03d_v2.0.1.nc"
# [21] [21]
# /app/nepcon/miniconda3/envs/dmd/lib/python3.12/site-packages/zarr/api/asynchronous.py:244: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(
# /tmp/ipykernel_19047/3579314230.py:2: UserWarning: The specified chunks separate the stored chunks along dimension "cycle_num" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_%03d_v2.0.1.nc"
# [22] [22]
# /app/nepcon/miniconda3/envs/dmd/lib/python3.12/site-packages/zarr/api/asynchronous.py:244: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(
# /tmp/ipykernel_19047/3579314230.py:2: UserWarning: The specified chunks separate the stored chunks along dimension "cycle_num" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   dsS = xr.open_dataset(op.join(ddir,"SWOT_with_IT/SWOT_L3_LR_SSH_HRET_CALVAL_%03d_v2.0.1.nc"
# [23] [23]
# /app/nepcon/miniconda3/envs/dmd/lib/python3.12/site-packages/zarr/api/asynchronous.py:244: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(
